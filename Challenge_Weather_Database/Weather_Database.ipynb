# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc
                         # "Country": city_country,
                         # "Date": city_date
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | vanimo
# Processing Record 4 of Set 1 | itaueira
# Processing Record 5 of Set 1 | srandakan
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | ahipara
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | chapadinha
# Processing Record 12 of Set 1 | touros
# Processing Record 13 of Set 1 | hirara
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | vestmannaeyjar
# Processing Record 16 of Set 1 | pedernales
# Processing Record 17 of Set 1 | marystown
# Processing Record 18 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | kaitangata
# Processing Record 22 of Set 1 | chapais
# Processing Record 23 of Set 1 | suao
# City not found. Skipping...
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | zhicheng
# Processing Record 28 of Set 1 | rochegda
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | harlingen
# Processing Record 31 of Set 1 | tosham
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | ust-tsilma
# Processing Record 34 of Set 1 | vanavara
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | acarau
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | muridke
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | bam
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | vila franca do campo
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | colares
# Processing Record 49 of Set 1 | airai
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | porto novo
# Processing Record 2 of Set 2 | yumen
# Processing Record 3 of Set 2 | stokmarknes
# Processing Record 4 of Set 2 | nizhniy odes
# Processing Record 5 of Set 2 | faro
# Processing Record 6 of Set 2 | gorontalo
# Processing Record 7 of Set 2 | okha
# Processing Record 8 of Set 2 | ostuacan
# Processing Record 9 of Set 2 | lagoa
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | progreso
# Processing Record 16 of Set 2 | paranaiba
# Processing Record 17 of Set 2 | qaqortoq
# Processing Record 18 of Set 2 | yazd
# Processing Record 19 of Set 2 | westport
# Processing Record 20 of Set 2 | pacific grove
# Processing Record 21 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 22 of Set 2 | svetlyy
# Processing Record 23 of Set 2 | torit
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | sokoni
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | beringovskiy
# Processing Record 28 of Set 2 | gazanjyk
# Processing Record 29 of Set 2 | mzimba
# Processing Record 30 of Set 2 | hobyo
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | dharchula
# Processing Record 33 of Set 2 | namatanai
# Processing Record 34 of Set 2 | zhigansk
# Processing Record 35 of Set 2 | gigmoto
# Processing Record 36 of Set 2 | lar
# Processing Record 37 of Set 2 | baghdad
# Processing Record 38 of Set 2 | chimoio
# Processing Record 39 of Set 2 | belomorsk
# Processing Record 40 of Set 2 | provost
# Processing Record 41 of Set 2 | terrak
# Processing Record 42 of Set 2 | kloulklubed
# Processing Record 43 of Set 2 | caravelas
# Processing Record 44 of Set 2 | qui nhon
# Processing Record 45 of Set 2 | sao filipe
# Processing Record 46 of Set 2 | iqaluit
# Processing Record 47 of Set 2 | popondetta
# Processing Record 48 of Set 2 | busselton
# Processing Record 49 of Set 2 | lompoc
# Processing Record 50 of Set 2 | cape town
# Processing Record 1 of Set 3 | manadhoo
# Processing Record 2 of Set 3 | naze
# Processing Record 3 of Set 3 | armizonskoye
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | joao pinheiro
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | shelburne
# Processing Record 8 of Set 3 | talnakh
# Processing Record 9 of Set 3 | saint george
# Processing Record 10 of Set 3 | hobart
# Processing Record 11 of Set 3 | kahului
# Processing Record 12 of Set 3 | namibe
# Processing Record 13 of Set 3 | kariba
# Processing Record 14 of Set 3 | fukue
# Processing Record 15 of Set 3 | umm lajj
# Processing Record 16 of Set 3 | pacifica
# Processing Record 17 of Set 3 | constitucion
# Processing Record 18 of Set 3 | nikolskoye
# Processing Record 19 of Set 3 | shestakovo
# Processing Record 20 of Set 3 | upata
# Processing Record 21 of Set 3 | monteiro
# Processing Record 22 of Set 3 | hovd
# Processing Record 23 of Set 3 | saint-francois
# Processing Record 24 of Set 3 | atambua
# Processing Record 25 of Set 3 | fortuna
# Processing Record 26 of Set 3 | kota kinabalu
# Processing Record 27 of Set 3 | ati
# Processing Record 28 of Set 3 | mahibadhoo
# Processing Record 29 of Set 3 | yima
# Processing Record 30 of Set 3 | byron bay
# Processing Record 31 of Set 3 | manokwari
# Processing Record 32 of Set 3 | tautira
# Processing Record 33 of Set 3 | ilulissat
# Processing Record 34 of Set 3 | cockburn town
# Processing Record 35 of Set 3 | aklavik
# Processing Record 36 of Set 3 | torbay
# Processing Record 37 of Set 3 | sakakah
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | kudahuvadhoo
# Processing Record 40 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 3 | grindavik
# Processing Record 42 of Set 3 | saint-philippe
# Processing Record 43 of Set 3 | oktyabrskoye
# Processing Record 44 of Set 3 | rawson
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | whitehorse
# Processing Record 48 of Set 3 | carnarvon
# Processing Record 49 of Set 3 | neiafu
# Processing Record 50 of Set 3 | san diego
# Processing Record 1 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | bambous virieux
# Processing Record 5 of Set 4 | vao
# Processing Record 6 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 4 | severo-kurilsk
# Processing Record 8 of Set 4 | butaritari
# Processing Record 9 of Set 4 | chuy
# Processing Record 10 of Set 4 | ulladulla
# Processing Record 11 of Set 4 | narsaq
# Processing Record 12 of Set 4 | bengkulu
# Processing Record 13 of Set 4 | barrow
# Processing Record 14 of Set 4 | hvolsvollur
# Processing Record 15 of Set 4 | jamestown
# Processing Record 16 of Set 4 | keflavik
# Processing Record 17 of Set 4 | murray bridge
# Processing Record 18 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 19 of Set 4 | kulgam
# Processing Record 20 of Set 4 | pangody
# Processing Record 21 of Set 4 | nouadhibou
# Processing Record 22 of Set 4 | ginir
# Processing Record 23 of Set 4 | atuona
# Processing Record 24 of Set 4 | pevek
# Processing Record 25 of Set 4 | aars
# Processing Record 26 of Set 4 | erzin
# Processing Record 27 of Set 4 | jinchang
# Processing Record 28 of Set 4 | maceio
# Processing Record 29 of Set 4 | pangnirtung
# Processing Record 30 of Set 4 | salalah
# Processing Record 31 of Set 4 | moussoro
# Processing Record 32 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 4 | arlit
# Processing Record 34 of Set 4 | ranfurly
# Processing Record 35 of Set 4 | egvekinot
# Processing Record 36 of Set 4 | charlestown
# Processing Record 37 of Set 4 | punto fijo
# Processing Record 38 of Set 4 | tura
# Processing Record 39 of Set 4 | poso
# Processing Record 40 of Set 4 | kharp
# Processing Record 41 of Set 4 | monze
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | ilebo
# Processing Record 44 of Set 4 | turbat
# Processing Record 45 of Set 4 | esperance
# Processing Record 46 of Set 4 | burgersdorp
# Processing Record 47 of Set 4 | souillac
# Processing Record 48 of Set 4 | buchanan
# Processing Record 49 of Set 4 | sitka
# Processing Record 50 of Set 4 | henties bay
# Processing Record 1 of Set 5 | ruteng
# Processing Record 2 of Set 5 | bardiyah
# Processing Record 3 of Set 5 | mahebourg
# Processing Record 4 of Set 5 | lavrentiya
# Processing Record 5 of Set 5 | faya
# Processing Record 6 of Set 5 | port elizabeth
# Processing Record 7 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 5 | tateyama
# Processing Record 9 of Set 5 | katsuura
# Processing Record 10 of Set 5 | vila
# Processing Record 11 of Set 5 | lodwar
# Processing Record 12 of Set 5 | gillette
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | high prairie
# Processing Record 16 of Set 5 | dunedin
# Processing Record 17 of Set 5 | lesosibirsk
# Processing Record 18 of Set 5 | rabo de peixe
# Processing Record 19 of Set 5 | khatanga
# Processing Record 20 of Set 5 | victoria
# Processing Record 21 of Set 5 | lethbridge
# Processing Record 22 of Set 5 | petropavlovka
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | bilma
# Processing Record 25 of Set 5 | afua
# Processing Record 26 of Set 5 | upernavik
# Processing Record 27 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 5 | novikovo
# Processing Record 29 of Set 5 | cabo san lucas
# Processing Record 30 of Set 5 | russell
# Processing Record 31 of Set 5 | tuktoyaktuk
# Processing Record 32 of Set 5 | kavieng
# Processing Record 33 of Set 5 | karpathos
# Processing Record 34 of Set 5 | haimen
# Processing Record 35 of Set 5 | georgetown
# Processing Record 36 of Set 5 | hambantota
# Processing Record 37 of Set 5 | nuuk
# Processing Record 38 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 5 | sambava
# Processing Record 40 of Set 5 | darnah
# Processing Record 41 of Set 5 | loyga
# Processing Record 42 of Set 5 | taunggyi
# Processing Record 43 of Set 5 | orange cove
# Processing Record 44 of Set 5 | margate
# Processing Record 45 of Set 5 | butler
# Processing Record 46 of Set 5 | prachuap khiri khan
# Processing Record 47 of Set 5 | port-gentil
# Processing Record 48 of Set 5 | carbonia
# Processing Record 49 of Set 5 | velestinon
# City not found. Skipping...
# Processing Record 50 of Set 5 | leh
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 2 of Set 6 | chokurdakh
# Processing Record 3 of Set 6 | lumby
# Processing Record 4 of Set 6 | horki
# Processing Record 5 of Set 6 | chama
# Processing Record 6 of Set 6 | betsiamites
# Processing Record 7 of Set 6 | escanaba
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | yoichi
# Processing Record 10 of Set 6 | fort nelson
# Processing Record 11 of Set 6 | half moon bay
# Processing Record 12 of Set 6 | san patricio
# Processing Record 13 of Set 6 | leningradskiy
# Processing Record 14 of Set 6 | morondava
# Processing Record 15 of Set 6 | valdez
# Processing Record 16 of Set 6 | prince rupert
# Processing Record 17 of Set 6 | alto parana
# Processing Record 18 of Set 6 | saryozek
# Processing Record 19 of Set 6 | linxia
# Processing Record 20 of Set 6 | havelock
# Processing Record 21 of Set 6 | qujing
# Processing Record 22 of Set 6 | cervo
# Processing Record 23 of Set 6 | saint-leu
# Processing Record 24 of Set 6 | kalmunai
# Processing Record 25 of Set 6 | lynchburg
# Processing Record 26 of Set 6 | provideniya
# Processing Record 27 of Set 6 | pauini
# Processing Record 28 of Set 6 | nome
# Processing Record 29 of Set 6 | roma
# Processing Record 30 of Set 6 | kwinana
# Processing Record 31 of Set 6 | krasnokamensk
# Processing Record 32 of Set 6 | codrington
# Processing Record 33 of Set 6 | san policarpo
# Processing Record 34 of Set 6 | broken hill
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | abu dhabi
# Processing Record 37 of Set 6 | muros
# Processing Record 38 of Set 6 | emerald
# Processing Record 39 of Set 6 | port hardy
# Processing Record 40 of Set 6 | grabouw
# Processing Record 41 of Set 6 | isangel
# Processing Record 42 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 6 | vila velha
# Processing Record 44 of Set 6 | bafata
# Processing Record 45 of Set 6 | itanagar
# Processing Record 46 of Set 6 | gweta
# Processing Record 47 of Set 6 | abu zabad
# Processing Record 48 of Set 6 | dranceni sat
# City not found. Skipping...
# Processing Record 49 of Set 6 | la ronge
# Processing Record 50 of Set 6 | riyadh
# Processing Record 1 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 7 | merauke
# Processing Record 3 of Set 7 | kaeo
# Processing Record 4 of Set 7 | sao felix do xingu
# Processing Record 5 of Set 7 | oruro
# Processing Record 6 of Set 7 | batagay-alyta
# Processing Record 7 of Set 7 | north bend
# Processing Record 8 of Set 7 | tilichiki
# Processing Record 9 of Set 7 | thompson
# Processing Record 10 of Set 7 | seoul
# Processing Record 11 of Set 7 | shengjin
# Processing Record 12 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 7 | kibungo
# Processing Record 14 of Set 7 | robe
# Processing Record 15 of Set 7 | kismayo
# Processing Record 16 of Set 7 | tiznit
# Processing Record 17 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 7 | jubb jannin
# City not found. Skipping...
# Processing Record 19 of Set 7 | port blair
# Processing Record 20 of Set 7 | krasnyy chikoy
# Processing Record 21 of Set 7 | halifax
# Processing Record 22 of Set 7 | boa vista
# Processing Record 23 of Set 7 | yulara
# Processing Record 24 of Set 7 | humberto de campos
# Processing Record 25 of Set 7 | chesma
# Processing Record 26 of Set 7 | rimouski
# Processing Record 27 of Set 7 | alofi
# Processing Record 28 of Set 7 | hwange
# Processing Record 29 of Set 7 | kyren
# Processing Record 30 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 31 of Set 7 | mount isa
# Processing Record 32 of Set 7 | monte carmelo
# Processing Record 33 of Set 7 | plettenberg bay
# Processing Record 34 of Set 7 | shasta lake
# Processing Record 35 of Set 7 | oxford
# Processing Record 36 of Set 7 | laibin
# Processing Record 37 of Set 7 | poum
# Processing Record 38 of Set 7 | bilibino
# Processing Record 39 of Set 7 | avera
# Processing Record 40 of Set 7 | luau
# Processing Record 41 of Set 7 | camocim
# Processing Record 42 of Set 7 | norman wells
# Processing Record 43 of Set 7 | stropkov
# Processing Record 44 of Set 7 | shahr-e babak
# Processing Record 45 of Set 7 | saravan
# Processing Record 46 of Set 7 | jibuti
# Processing Record 47 of Set 7 | ugoofaaru
# Processing Record 48 of Set 7 | midland
# Processing Record 49 of Set 7 | ikom
# Processing Record 50 of Set 7 | mezen
# Processing Record 1 of Set 8 | tpig
# Processing Record 2 of Set 8 | comodoro rivadavia
# Processing Record 3 of Set 8 | saldanha
# Processing Record 4 of Set 8 | camacha
# Processing Record 5 of Set 8 | gohpur
# Processing Record 6 of Set 8 | dingle
# Processing Record 7 of Set 8 | batagay
# Processing Record 8 of Set 8 | de aar
# Processing Record 9 of Set 8 | tuatapere
# Processing Record 10 of Set 8 | te anau
# Processing Record 11 of Set 8 | korla
# Processing Record 12 of Set 8 | hami
# Processing Record 13 of Set 8 | the pas
# Processing Record 14 of Set 8 | manzhouli
# Processing Record 15 of Set 8 | hofn
# Processing Record 16 of Set 8 | buraydah
# Processing Record 17 of Set 8 | inta
# Processing Record 18 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 19 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 8 | baruun-urt
# Processing Record 21 of Set 8 | chitral
# Processing Record 22 of Set 8 | kavaratti
# Processing Record 23 of Set 8 | chantada
# Processing Record 24 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 8 | zverinogolovskoye
# Processing Record 26 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 8 | broome
# Processing Record 28 of Set 8 | esso
# Processing Record 29 of Set 8 | sungairaya
# Processing Record 30 of Set 8 | huangmei
# Processing Record 31 of Set 8 | verkhnyaya inta
# Processing Record 32 of Set 8 | sao joao da barra
# Processing Record 33 of Set 8 | kushima
# Processing Record 34 of Set 8 | ascension
# Processing Record 35 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 8 | gat
# Processing Record 37 of Set 8 | salinopolis
# Processing Record 38 of Set 8 | saint-pierre
# Processing Record 39 of Set 8 | aktau
# Processing Record 40 of Set 8 | itaituba
# Processing Record 41 of Set 8 | kathu
# Processing Record 42 of Set 8 | macas
# Processing Record 43 of Set 8 | itarema
# Processing Record 44 of Set 8 | puerto escondido
# Processing Record 45 of Set 8 | cayenne
# Processing Record 46 of Set 8 | biak
# Processing Record 47 of Set 8 | bongandanga
# Processing Record 48 of Set 8 | hellvik
# Processing Record 49 of Set 8 | kununurra
# Processing Record 50 of Set 8 | otradnoye
# Processing Record 1 of Set 9 | anloga
# Processing Record 2 of Set 9 | cidreira
# Processing Record 3 of Set 9 | chumikan
# Processing Record 4 of Set 9 | santiago del estero
# Processing Record 5 of Set 9 | saint anthony
# Processing Record 6 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 9 | rameshki
# Processing Record 8 of Set 9 | nalhati
# Processing Record 9 of Set 9 | pochutla
# Processing Record 10 of Set 9 | mahon
# Processing Record 11 of Set 9 | hithadhoo
# Processing Record 12 of Set 9 | soure
# Processing Record 13 of Set 9 | rio grande
# Processing Record 14 of Set 9 | katherine
# Processing Record 15 of Set 9 | sundumbili
# Processing Record 16 of Set 9 | tecoanapa
# Processing Record 17 of Set 9 | dali
# Processing Record 18 of Set 9 | matagami
# Processing Record 19 of Set 9 | aksarayskiy
# Processing Record 20 of Set 9 | galveston
# Processing Record 21 of Set 9 | sobolevo
# Processing Record 22 of Set 9 | waipawa
# Processing Record 23 of Set 9 | oktyabrskiy
# Processing Record 24 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 25 of Set 9 | kangaatsiaq
# Processing Record 26 of Set 9 | meulaboh
# Processing Record 27 of Set 9 | northam
# Processing Record 28 of Set 9 | khandbari
# Processing Record 29 of Set 9 | eureka
# Processing Record 30 of Set 9 | maralal
# Processing Record 31 of Set 9 | mehran
# Processing Record 32 of Set 9 | ndola
# Processing Record 33 of Set 9 | kargasok
# Processing Record 34 of Set 9 | general roca
# Processing Record 35 of Set 9 | talca
# Processing Record 36 of Set 9 | pringsewu
# Processing Record 37 of Set 9 | madang
# Processing Record 38 of Set 9 | gondanglegi
# Processing Record 39 of Set 9 | whitianga
# Processing Record 40 of Set 9 | santa cruz cabralia
# Processing Record 41 of Set 9 | boende
# Processing Record 42 of Set 9 | karratha
# Processing Record 43 of Set 9 | alto araguaia
# Processing Record 44 of Set 9 | neepawa
# Processing Record 45 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 9 | ouesso
# Processing Record 47 of Set 9 | cap malheureux
# Processing Record 48 of Set 9 | labrea
# Processing Record 49 of Set 9 | nhulunbuy
# Processing Record 50 of Set 9 | rocha
# Processing Record 1 of Set 10 | pyapon
# Processing Record 2 of Set 10 | vardo
# Processing Record 3 of Set 10 | rundu
# Processing Record 4 of Set 10 | anadyr
# Processing Record 5 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 10 | palmer
# Processing Record 7 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 10 | mpanda
# Processing Record 9 of Set 10 | talcahuano
# Processing Record 10 of Set 10 | laguna
# Processing Record 11 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 10 | sovetskaya gavan
# Processing Record 13 of Set 10 | beitbridge
# Processing Record 14 of Set 10 | monteria
# Processing Record 15 of Set 10 | kirakira
# Processing Record 16 of Set 10 | alice springs
# Processing Record 17 of Set 10 | tatarsk
# Processing Record 18 of Set 10 | san pedro buenavista
# Processing Record 19 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 20 of Set 10 | santa rosa
# Processing Record 21 of Set 10 | tutoia
# Processing Record 22 of Set 10 | geraldton
# Processing Record 23 of Set 10 | tabas
# Processing Record 24 of Set 10 | chinsali
# Processing Record 25 of Set 10 | alexandria
# Processing Record 26 of Set 10 | seguin
# Processing Record 27 of Set 10 | los llanos de aridane
# Processing Record 28 of Set 10 | chicama
# Processing Record 29 of Set 10 | solnechnyy
# Processing Record 30 of Set 10 | barranca
# Processing Record 31 of Set 10 | dawei
# Processing Record 32 of Set 10 | monte alegre
# Processing Record 33 of Set 10 | mlimba
# Processing Record 34 of Set 10 | kachiry
# Processing Record 35 of Set 10 | bubaque
# Processing Record 36 of Set 10 | amahai
# Processing Record 37 of Set 10 | euclid
# Processing Record 38 of Set 10 | balykshi
# Processing Record 39 of Set 10 | lopatino
# Processing Record 40 of Set 10 | olafsvik
# Processing Record 41 of Set 10 | damietta
# Processing Record 42 of Set 10 | senno
# Processing Record 43 of Set 10 | krasnoselkup
# Processing Record 44 of Set 10 | kenai
# Processing Record 45 of Set 10 | magdagachi
# Processing Record 46 of Set 10 | kupang
# Processing Record 47 of Set 10 | aksarka
# Processing Record 48 of Set 10 | ames
# Processing Record 49 of Set 10 | mujiayingzi
# Processing Record 50 of Set 10 | la tuque
# Processing Record 1 of Set 11 | kargil
# Processing Record 2 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 11 | seydi
# Processing Record 4 of Set 11 | brae
# Processing Record 5 of Set 11 | srivardhan
# Processing Record 6 of Set 11 | grand gaube
# Processing Record 7 of Set 11 | axim
# Processing Record 8 of Set 11 | astara
# Processing Record 9 of Set 11 | bud
# Processing Record 10 of Set 11 | haines junction
# Processing Record 11 of Set 11 | pestravka
# Processing Record 12 of Set 11 | aripuana
# Processing Record 13 of Set 11 | quatre cocos
# Processing Record 14 of Set 11 | hamilton
# Processing Record 15 of Set 11 | kytmanovo
# Processing Record 16 of Set 11 | mongu
# Processing Record 17 of Set 11 | locri
# Processing Record 18 of Set 11 | yar-sale
# Processing Record 19 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 11 | ekhabi
# Processing Record 22 of Set 11 | ixtapa
# Processing Record 23 of Set 11 | hede
# Processing Record 24 of Set 11 | necochea
# Processing Record 25 of Set 11 | kirkenes
# Processing Record 26 of Set 11 | karakol
# Processing Record 27 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 28 of Set 11 | mokrousovo
# Processing Record 29 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 11 | tessalit
# Processing Record 32 of Set 11 | barcelos
# Processing Record 33 of Set 11 | warren
# Processing Record 34 of Set 11 | kyaikto
# Processing Record 35 of Set 11 | tiarei
# Processing Record 36 of Set 11 | higuey
# City not found. Skipping...
# Processing Record 37 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 11 | bowen
# Processing Record 39 of Set 11 | lensk
# Processing Record 40 of Set 11 | mandla
# Processing Record 41 of Set 11 | tres arroyos
# Processing Record 42 of Set 11 | amberley
# Processing Record 43 of Set 11 | wattegama
# Processing Record 44 of Set 11 | garm
# City not found. Skipping...
# Processing Record 45 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 46 of Set 11 | kemin
# Processing Record 47 of Set 11 | gunjur
# Processing Record 48 of Set 11 | makat
# Processing Record 49 of Set 11 | yuanping
# Processing Record 50 of Set 11 | pundaguitan
# Processing Record 1 of Set 12 | tazovskiy
# Processing Record 2 of Set 12 | mayor pablo lagerenza
# Processing Record 3 of Set 12 | tomaszow lubelski
# Processing Record 4 of Set 12 | ketou
# Processing Record 5 of Set 12 | golden
# Processing Record 6 of Set 12 | ayan
# Processing Record 7 of Set 12 | nishihara
# Processing Record 8 of Set 12 | sumbe
# Processing Record 9 of Set 12 | mitu
# Processing Record 10 of Set 12 | visnes
# Processing Record 11 of Set 12 | pokrovskoye
# Processing Record 12 of Set 12 | san quintin
# Processing Record 13 of Set 12 | beyneu
# Processing Record 14 of Set 12 | pujili
# Processing Record 15 of Set 12 | vesyegonsk
# Processing Record 16 of Set 12 | hualmay
# Processing Record 17 of Set 12 | ta khmau
# Processing Record 18 of Set 12 | balkanabat
# Processing Record 19 of Set 12 | polyarnyy
# Processing Record 20 of Set 12 | iberia
# Processing Record 21 of Set 12 | bontang
# Processing Record 22 of Set 12 | morant bay
# Processing Record 23 of Set 12 | zheleznodorozhnyy
# Processing Record 24 of Set 12 | padang
# Processing Record 25 of Set 12 | rondonopolis
# Processing Record 26 of Set 12 | sola
# Processing Record 27 of Set 12 | mackay
# Processing Record 28 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 12 | hohhot
# Processing Record 30 of Set 12 | erdenet
# Processing Record 31 of Set 12 | kayankulam
# Processing Record 32 of Set 12 | port hedland
# Processing Record 33 of Set 12 | asau
# Processing Record 34 of Set 12 | ozernovskiy
# Processing Record 35 of Set 12 | svetlaya
# Processing Record 36 of Set 12 | wanaka
# Processing Record 37 of Set 12 | komsomolskiy
# Processing Record 38 of Set 12 | nabire
# Processing Record 39 of Set 12 | jeremie
# Processing Record 40 of Set 12 | verkhnevilyuysk
# Processing Record 41 of Set 12 | remedios
# Processing Record 42 of Set 12 | ngunguru
# Processing Record 43 of Set 12 | guarapari
# Processing Record 44 of Set 12 | morrope
# Processing Record 45 of Set 12 | xining
# Processing Record 46 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 47 of Set 12 | kanniyakumari
# Processing Record 48 of Set 12 | taywarah
# Processing Record 49 of Set 12 | daltenganj
# Processing Record 50 of Set 12 | rivadavia
# Processing Record 1 of Set 13 | poopo
# Processing Record 2 of Set 13 | sabang
# Processing Record 3 of Set 13 | mkushi
# Processing Record 4 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 5 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 13 | dryden
# Processing Record 7 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 13 | pavilosta
# Processing Record 9 of Set 13 | marzuq
# Processing Record 10 of Set 13 | kikwit
# Processing Record 11 of Set 13 | bandarbeyla
# Processing Record 12 of Set 13 | yerbogachen
# Processing Record 13 of Set 13 | derac
# Processing Record 14 of Set 13 | luderitz
# Processing Record 15 of Set 13 | viseu
# Processing Record 16 of Set 13 | mubende
# Processing Record 17 of Set 13 | oppdal
# Processing Record 18 of Set 13 | zhuanghe
# Processing Record 19 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 20 of Set 13 | veraval
# Processing Record 21 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 22 of Set 13 | swan hill
# Processing Record 23 of Set 13 | elizabeth city
# Processing Record 24 of Set 13 | sur
# Processing Record 25 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 26 of Set 13 | basco
# Processing Record 27 of Set 13 | saint-augustin
# Processing Record 28 of Set 13 | parit buntar
# Processing Record 29 of Set 13 | surgut
# Processing Record 30 of Set 13 | santa rosalia
# Processing Record 31 of Set 13 | kashan
# Processing Record 32 of Set 13 | husavik
# Processing Record 33 of Set 13 | college
# Processing Record 34 of Set 13 | srednekolymsk
# Processing Record 35 of Set 13 | marquette
# Processing Record 36 of Set 13 | nemuro
# Processing Record 37 of Set 13 | okhotsk
# Processing Record 38 of Set 13 | udachnyy
# Processing Record 39 of Set 13 | san carlos de bariloche
# Processing Record 40 of Set 13 | houma
# Processing Record 41 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 42 of Set 13 | shimoda
# Processing Record 43 of Set 13 | severo-yeniseyskiy
# Processing Record 44 of Set 13 | jahangirpur
# Processing Record 45 of Set 13 | san cristobal
# Processing Record 46 of Set 13 | bunia
# Processing Record 47 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 48 of Set 13 | ostrovnoy
# Processing Record 49 of Set 13 | kamenka
# Processing Record 50 of Set 13 | redlands
# Processing Record 1 of Set 14 | mastic beach
# Processing Record 2 of Set 14 | copiapo
# Processing Record 3 of Set 14 | opobo
# City not found. Skipping...
# Processing Record 4 of Set 14 | novoagansk
# Processing Record 5 of Set 14 | japura
# Processing Record 6 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 14 | nortelandia
# Processing Record 8 of Set 14 | bathsheba
# Processing Record 9 of Set 14 | omboue
# Processing Record 10 of Set 14 | tam ky
# Processing Record 11 of Set 14 | road town
# Processing Record 12 of Set 14 | mitsamiouli
# Processing Record 13 of Set 14 | taybad
# Processing Record 14 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 15 of Set 14 | prado
# Processing Record 16 of Set 14 | staszow
# Processing Record 17 of Set 14 | almaznyy
# Processing Record 18 of Set 14 | pailon
# Processing Record 19 of Set 14 | bloomsburg
# Processing Record 20 of Set 14 | plouzane
# Processing Record 21 of Set 14 | aneho
# Processing Record 22 of Set 14 | praya
# Processing Record 23 of Set 14 | havre-saint-pierre
# Processing Record 24 of Set 14 | we
# City not found. Skipping...
# Processing Record 25 of Set 14 | zapolyarnyy
# Processing Record 26 of Set 14 | kathmandu
# Processing Record 27 of Set 14 | ulaangom
# Processing Record 28 of Set 14 | chingirlau
# Processing Record 29 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 30 of Set 14 | puerto leguizamo
# Processing Record 31 of Set 14 | stonewall
# Processing Record 32 of Set 14 | narasannapeta
# Processing Record 33 of Set 14 | terney
# Processing Record 34 of Set 14 | belaya gora
# Processing Record 35 of Set 14 | tonaya
# Processing Record 36 of Set 14 | shangrao
# Processing Record 37 of Set 14 | uspenka
# Processing Record 38 of Set 14 | jieshi
# Processing Record 39 of Set 14 | ornskoldsvik
# Processing Record 40 of Set 14 | marsh harbour
# Processing Record 41 of Set 14 | sao joaquim
# Processing Record 42 of Set 14 | roebourne
# Processing Record 43 of Set 14 | hjelset
# Processing Record 44 of Set 14 | port macquarie
# Processing Record 45 of Set 14 | middelburg
# Processing Record 46 of Set 14 | sabha
# Processing Record 47 of Set 14 | birao
# Processing Record 48 of Set 14 | zelenogorskiy
# Processing Record 49 of Set 14 | vrangel
# Processing Record 50 of Set 14 | lamar
# Processing Record 1 of Set 15 | bethanien
# Processing Record 2 of Set 15 | kampot
# Processing Record 3 of Set 15 | fairbanks
# Processing Record 4 of Set 15 | thinadhoo
# Processing Record 5 of Set 15 | zhangye
# Processing Record 6 of Set 15 | kampong thum
# Processing Record 7 of Set 15 | aberdeen
# Processing Record 8 of Set 15 | lagunas
# Processing Record 9 of Set 15 | mount vernon
# Processing Record 10 of Set 15 | agutaya
# Processing Record 11 of Set 15 | turukhansk
# Processing Record 12 of Set 15 | manado
# Processing Record 13 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 15 | ambon
# Processing Record 15 of Set 15 | hall
# Processing Record 16 of Set 15 | korcula
# Processing Record 17 of Set 15 | andijon
# Processing Record 18 of Set 15 | zimmi
# Processing Record 19 of Set 15 | walvis bay
# Processing Record 20 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 21 of Set 15 | opuwo
# Processing Record 22 of Set 15 | boueni
# Processing Record 23 of Set 15 | mayna
# Processing Record 24 of Set 15 | taree
# Processing Record 25 of Set 15 | umea
# Processing Record 26 of Set 15 | mbacke
# City not found. Skipping...
# Processing Record 27 of Set 15 | kihei
# Processing Record 28 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 29 of Set 15 | saint-georges
# Processing Record 30 of Set 15 | altamira
# Processing Record 31 of Set 15 | manga
# Processing Record 32 of Set 15 | balimo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ponta Do Sol      PT  32.6667  -17.1000     69.71        66          65
# 1        Vanimo      PG  -2.6741  141.3028     84.61        73          60
# 2      Itaueira      BR  -7.6033  -43.0256     78.89        43          69
# 3     Srandakan      ID  -7.9386  110.2506     84.79        73          99
# 4        Dikson      RU  73.5069   80.5464      9.10        86         100
# 5       Rikitea      PF -23.1203 -134.9692     75.52        81          45
# 6       Ushuaia      AR -54.8000  -68.3000     55.06        50          40
# 7       Ahipara      NZ -35.1667  173.1667     63.48        75           2
# 8    Chapadinha      BR  -3.7417  -43.3603     73.38        90          66
# 9        Touros      BR  -5.1989  -35.4608     77.90        79          52
#
#    Wind Speed Current Description
# 0        7.96       broken clouds
# 1        7.16       broken clouds
# 2        5.06       broken clouds
# 3       10.74     overcast clouds
# 4        6.04     overcast clouds
# 5       16.73    scattered clouds
# 6        5.75    scattered clouds
# 7       10.83           clear sky
# 8        3.20       broken clouds
# 9       12.75       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
